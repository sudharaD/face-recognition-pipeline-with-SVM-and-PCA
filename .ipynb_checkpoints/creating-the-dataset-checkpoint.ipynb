# %%
# Import libraries
import os
import numpy as np
import pandas as pd

# %%
# Load images one by one

# %%
# Convert to grey scale

# %%
# Face detection and face crop

# %%
# Resize 50 x 50

# %%
# Flatten to 2500

# %%
# Append to the dataset
